# %% [markdown]
# # Sentiment Classification
#
#
# ### Generate Word Embeddings and retrieve outputs of each layer with Keras based on Classification task
#
# Word embeddings are a type of word representation that allows words with similar meaning to have a similar representation.
#
# It is a distributed representation for text that is perhaps one of the key breakthroughs for the impressive performance of deep learning methods on challenging natural language processing problems.
#
# We willl use the imdb dataset to learn word embeddings as we train our dataset. This dataset contains 25,000 movie reviews from IMDB, labeled with sentiment (positive or negative).
#
#
#
# ### Dataset
#
# `from keras.datasets import imdb`
#
# Dataset of 25,000 movies reviews from IMDB, labeled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes (integers). For convenience, the words are indexed by their frequency in the dataset, meaning the for that has index 1 is the most frequent word. Use the first 20 words from each review to speed up training, using a max vocab size of 10,000.
#
# As a convention, "0" does not stand for a specific word, but instead is used to encode any unknown word.
#
#
# ### Aim
#
# 1. Import test and train data
# 2. Import the labels ( train and test)
# 3. Get the word index and then Create key value pair for word and word_id. (12.5 points)
# 4. Build a Sequential Model using Keras for Sentiment Classification task. (10 points)
# 5. Report the Accuracy of the model. (5 points)
# 6. Retrive the output of each layer in keras for a given single test sample from the trained model you built. (2.5 points)

# %% [markdown]
# #### Usage:

# %%
from keras.datasets import imdb

vocab_size = 10000 #vocab size

import numpy as np
# save np.load
np_load_old = np.load

# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size) # vocab_size is no.of words to consider from the dataset, ordering based on frequency.

np.load = np_load_old

# %%
print(y_train)
print(x_train)
# Out:
# [1 0 0 ... 0 1 0]
# [list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32])
#  list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 2, 4, 1153, 9, 194, 775, 7, 8255, 2, 349, 2637, 148, 605, 2, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95])
#  list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113])
#  ...
#  list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 2, 325, 725, 134, 2, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 2, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 2, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 2, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 2, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 2, 5, 27, 710, 117, 2, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 2, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 2, 7750, 5, 4241, 18, 4, 8497, 2, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 2, 4, 3586, 2])
#  list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 2, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23])
#  list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 2, 270, 2, 5, 2, 2, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 2, 21, 27, 9685, 6139, 5, 2, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 2, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 2, 2, 544, 5, 383, 1271, 848, 1468, 2, 497, 2, 8, 1597, 8778, 2, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])]

# %%
from keras.preprocessing.sequence import pad_sequences
vocab_size = 10000 #vocab size
maxlen = 300  #number of word used from each review

# %%
#load dataset as a list of ints
# (x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)
#make all sequences of the same length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test =  pad_sequences(x_test, maxlen=maxlen)

# %%
print(x_train)
# Out:
# [[   0    0    0 ...   19  178   32]
#  [   0    0    0 ...   16  145   95]
#  [   0    0    0 ...    7  129  113]
#  ...
#  [   0    0    0 ...    4 3586    2]
#  [   0    0    0 ...   12    9   23]
#  [   0    0    0 ...  204  131    9]]

# %%
len(x_train)
# Out:
# 25000

# %% [markdown]
# ## Build Keras Embedding Layer Model
# We can think of the Embedding layer as a dicionary that maps a index assigned to a word to a word vector. This layer is very flexible and can be used in a few ways:
#
# * The embedding layer can be used at the start of a larger deep learning model.
# * Also we could load pre-train word embeddings into the embedding layer when we create our model.
# * Use the embedding layer to train our own word2vec models.
#
# The keras embedding layer doesn't require us to onehot encode our words, instead we have to give each word a unqiue intger number as an id. For the imdb dataset we've loaded this has already been done, but if this wasn't the case we could use sklearn [LabelEncoder](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# W0105 11:33:42.224056 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0105 11:33:42.244613 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0105 11:33:42.252727 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0105 11:33:42.398737 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0105 11:33:42.412300 139806407391104 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# W0105 11:33:59.965645 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0105 11:33:59.994322 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0105 11:34:00.000103 139806407391104 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 300, 32)           320000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               82432
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 402,561
# Trainable params: 402,561
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
train_history = model.fit(x_train, y_train, epochs=3, batch_size=64)
# Out:
# W0105 11:34:37.872343 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0105 11:34:37.980645 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0105 11:34:38.053373 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0105 11:34:38.058243 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0105 11:34:38.059344 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# Epoch 1/3
# W0105 11:34:39.494744 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0105 11:34:39.496746 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W0105 11:34:39.672228 139806407391104 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 25000/25000 [==============================] - 267s 11ms/step - loss: 0.5084 - acc: 0.7517
# Epoch 2/3
# 25000/25000 [==============================] - 256s 10ms/step - loss: 0.3530 - acc: 0.8544
# Epoch 3/3
# 25000/25000 [==============================] - 256s 10ms/step - loss: 0.2979 - acc: 0.8811

# %%
y_pred = model.predict(x_test, verbose=0)

# %%
print(y_pred)
# Out:
# [[0.514057  ]
#  [0.98426056]
#  [0.55813354]
#  ...
#  [0.11214623]
#  [0.53228116]
#  [0.95410895]]

# %%
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred.round())
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.854800

# %% [markdown]
# ## Retrive the output of each layer in keras for a given single test sample from the trained model you built

# %%
index = imdb.get_word_index()
reverse_index = dict([(value, key) for (key, value) in index.items()]) 
decoded = " ".join( [reverse_index.get(i - 10, "#") for i in x_test[0]] )
print(decoded)
# Out:
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # alone enough of not # silly # # # # # # try # # going clueless let line # acting # spoilers spoilers spoilers # # a other little also sound irritated made but compare of not was movie lunatic film point becomes # little of maybe funny # now from # movie guy is same # one you for irritated overall enough of # silly

# %%
x = 0
SentimentDict={1:'positive', 0:'negative'}
for i,j in zip(y_test,y_pred):
  print('+')
  print(i,j[0])
  print('label: ', SentimentDict[i], ', prediction: ', SentimentDict[j.round()[0]])
  x = x+1
# Out:
# +
# (0, 0.514057)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.98426056)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.55813354)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.58566064)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.99458516)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.94027936)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9723456)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.044695407)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.9707764)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.9520333)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.8765589)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.049221843)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.022051632)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.023028672)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9959141)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.017027676)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9890441)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.5138269)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.0072779953)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.051411748)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9967809)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.97423565)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.8182237)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.98463905)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9856251)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.99186176)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.029387027)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9896229)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9612156)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.028593391)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9851546)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9517311)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.52696764)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.010756373)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.037486434)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.014221162)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.8728756)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.97477984)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.9476749)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.0069529116)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9983084)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9803009)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.017877668)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.98196995)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9942162)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.65148544)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.12191996)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.007073939)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.017104805)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.7867783)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.03992191)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.9647515)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.9133134)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.8901203)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.983733)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.40962893)
# ('label: ', 'positive', ', prediction: ', 'negative')
# +
# (1, 0.6473447)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9751644)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.045299202)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.3438623)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.14730501)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.007765591)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.99442875)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.0141173005)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.014954746)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9921545)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.96829593)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.93239516)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.97143376)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9867325)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9302332)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.99068475)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.89582825)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.027535796)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.022260845)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.98002267)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.028119713)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.93805814)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.42133763)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.0071163774)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.84664845)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.15967846)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.44789478)
# ('label: ', 'positive', ', prediction: ', 'negative')
# +
# (1, 0.9035319)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.06813082)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.03077504)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.09902325)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9777641)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.048161924)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9899324)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.98638403)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.8312341)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.25836176)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.6691564)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9808594)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.84876025)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.9657859)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.99291)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.029565603)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.010902107)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.16969728)
# ('label: ', 'positive', ', prediction: ', 'negative')
# +
# (1, 0.25074035)
# ('label: ', 'positive', ', prediction: ', 'negative')
# +
# (0, 0.21312886)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.17197919)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.089466035)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.026946187)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.31649286)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.021944076)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.97109854)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.99097395)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9943812)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.009616911)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.9347832)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.15926969)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.012673885)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.62357426)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (1, 0.9776059)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.020687342)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.85592335)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.959259)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.11315808)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.6773101)
# ('label: ', 'negative', ', prediction: ', 'positive')
# +
# (0, 0.1425449)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.9924211)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9808657)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9327352)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (1, 0.9005026)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0.014991164)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.008373916)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (0, 0.07724574)
# ('label: ', 'negative', ', prediction: ', 'negative')
# +
# (1, 0.68184155)
# ('label: ', 'positive', ', prediction: ', 'positive')
# +
# (0, 0